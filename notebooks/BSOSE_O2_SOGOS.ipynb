# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cmocean as cmo
import gsw

# %%
ddir = '/swot/SUM05/dbalwada/BSOSE/'

# %%
ds_O2 = xr.open_dataset(ddir+ 'bsose_Iter135_2013to2019_5day_O2.nc')
ds_T  = xr.open_dataset(ddir+ 'bsose_Iter135_2013to2019_5day_Theta.nc')
ds_S  = xr.open_dataset(ddir+ 'bsose_Iter135_2013to2019_5day_Salt.nc')

# %%
ds_T.time
# Out:
# <xarray.DataArray 'time' (time: 511)>
# array(['2013-01-05T00:00:00.000000000', '2013-01-10T00:00:00.000000000',
#        '2013-01-15T00:00:00.000000000', ..., '2019-12-20T00:00:00.000000000',
#        '2019-12-25T00:00:00.000000000', '2019-12-30T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#     iter     (time) int64 ...
#   * time     (time) datetime64[ns] 2013-01-05 2013-01-10 ... 2019-12-30
# Attributes:
#     standard_name:  time
#     long_name:      Time
#     axis:           T

# %%
ds_T.THETA.sel(XC=slice(20, 50), YC=slice(-62, -40)
        ).sel(time='2019-05-01', method='nearest'
             ).sel(Z=-300, method='nearest').plot(vmin=-1, vmax=5)

# %%
20/180
# Out:
# 0.1111111111111111
